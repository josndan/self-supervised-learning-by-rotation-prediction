# %%
from google.colab import drive
drive.mount('/content/drive')

FOLDERNAME = "CS682/R2/dataset/"
assert FOLDERNAME is not None, "[!] Enter the foldername."

import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# %cd /content/drive/My\ Drive/$FOLDERNAME
# %config InlineBackend.figure_format = 'svg'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/CS682/R2/dataset

# %%
# !pip install fiftyone
# !pip uninstall opencv-python-headless==4.5.5.62
# !pip install opencv-python-headless==4.5.2.52
# !pip uninstall requests
# !pip install requests==2.26.0
# !pip uninstall xmla

# %%
import fiftyone as fo
import fiftyone.zoo as foz

# Download and load the validation split of COCO-2017
dataset = foz.load_zoo_dataset("coco-2017", split="test",
                               label_types=["detections"],classes=["cat", "dog"]
                               )

session = fo.launch_app(dataset)
# Out:
# NumExpr defaulting to 2 threads.
# ...
# Test split is unlabeled; ignoring classes requirement
# ...
#  100% |██████|    8.7Mb/8.7Mb [384.1ms elapsed, 0s remaining, 22.7Mb/s]
# Extracting test info to '/root/fiftyone/coco-2017/raw/image_info_test2017.json'
# ...
#  100% |█████|   49.5Gb/49.5Gb [2.3m elapsed, 0s remaining, 364.5Mb/s]
# Extracting images to '/root/fiftyone/coco-2017/test/data'
# Writing annotations to '/root/fiftyone/coco-2017/test/labels.json'
# Dataset info written to '/root/fiftyone/coco-2017/info.json'
# Loading 'coco-2017' split 'test'
# Dataset is unlabeled; ignoring classes requirement
#  100% |█████████████| 40670/40670 [24.9s elapsed, 0s remaining, 1.7K samples/s]
# Dataset 'coco-2017-test' created
# <style>
#
# @import url("https://fonts.googleapis.com/css2?family=Palanquin&display=swap");
#
# #focontainer-caaae66c-6b8d-4f0c-ba55-601cc8a2869b {
#   position: relative;
#   display: block !important;
# }
# #foactivate-caaae66c-6b8d-4f0c-ba55-601cc8a2869b {
# ...

# %%
export_dir = "./COCO/test/data/"

# The name of the sample field containing the label that you wish to export
# Used when exporting labeled datasets (e.g., classification or detection)
label_field = "ground_truth"  # for example

# The type of dataset to export
# Any subclass of `fiftyone.types.Dataset` is supported
dataset_type = fo.types.COCODetectionDataset  # for example

# Export the dataset
dataset.export(
    data_path=export_dir,
    labels_path="./COCO/test/labels.json",
    dataset_type=dataset_type,
    label_field=label_field,
)
drive.flush_and_unmount()
# Out:
#    2% ||------------|   866/40670 [15.6s elapsed, 11.9m remaining, 76.3 samples/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-ff049bcfb4db> in <module>()
#      14     labels_path="./COCO/test/labels.json",
#      15     dataset_type=dataset_type,
# ---> 16     label_field=label_field,
#      17 )
#      18 drive.flush_and_unmount()
#
# /usr/local/lib/python3.7/dist-packages/fiftyone/core/collections.py in export(self, export_dir, dataset_type, data_path, labels_path, export_media, dataset_exporter, label_field, frame_labels_field, overwrite, **kwargs)
#    6133             frame_labels_field=frame_labels_field,
#    6134             overwrite=overwrite,
# -> 6135             **kwargs,
#    6136         )
#    6137
#
# ...
